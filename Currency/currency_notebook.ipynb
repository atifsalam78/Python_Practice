# %%
import pandas as pd
from datetime import datetime
import os

def fetch_currency_data(url):
    """Fetch currency data from the website"""
    try:
        data = pd.read_html(url)
        return data[11]
    except Exception as e:
        print(f"Failed to fetch data from {url}: {e}")
        return None

def process_currency_data(data):
    """Process the currency data"""
    if data is None:
        return None
    
    # Rename columns
    data = data.rename(columns={0: "FROM_CURRENCY", 1: "Buying", 2: "CONVERSION_RATE"})
    
    # Drop unnecessary column
    data = data.drop("Buying", axis=1)
    
    # Add new columns
    current_date = datetime.today().strftime("%d-%b-%Y")
    data = data.assign(
        TO_CURRENCY="PKR",
        CONVERSION_DATE=current_date,
        CONVERSION_TYPE="Corporate",
        STATUS_CODE="C",
        CREATION_DATE=current_date,
        CREATED_BY="1115",
        LAST_UPDATE_DATE=current_date,
        LAST_UPDATED_BY="1115",
        LAST_UPDATE_LOGIN="1115"
    )
    
    data = data.reindex(columns=["FROM_CURRENCY", "TO_CURRENCY", "CONVERSION_DATE", "CONVERSION_TYPE", "CONVERSION_RATE", "STATUS_CODE", "CREATION_DATE", "CREATED_BY", "LAST_UPDATE_DATE", "LAST_UPDATED_BY", "LAST_UPDATE_LOGIN"])
    # data = data[data.FROM_CURRENCY.isin(["US Dollar", "Euro", "UK Pound Sterling"])]
    return data


def add_new_row(data):  
    """Add a new row in between each row"""  
    rows = []  
    for index, row in data.iterrows():  
        rows.append(row)  
        if index <= len(data) - 1:  
            new_row = pd.Series({  
                "FROM_CURRENCY": "PKR",  
                "TO_CURRENCY": data.FROM_CURRENCY.values[index],  
                "CONVERSION_DATE": datetime.today().strftime("%d-%b-%Y"),  
                "CONVERSION_TYPE": "Corporate",  
                "CONVERSION_RATE": 1/data.CONVERSION_RATE.values[index],  
                "STATUS_CODE": "C",  
                "CREATION_DATE": datetime.today().strftime("%d-%b-%Y"),  
                "CREATED_BY": "1115",  
                "LAST_UPDATE_DATE": datetime.today().strftime("%d-%b-%Y"),  
                "LAST_UPDATED_BY": "1115",  
                "LAST_UPDATE_LOGIN": "1115"
            })  
            rows.append(new_row)  
    
    updated_data = pd.DataFrame(rows)

    updated_data['FROM_CURRENCY'] = updated_data['FROM_CURRENCY'].replace({  
        "US Dollar": "USD",  
        "Euro": "Eur",  
        "UK Pound Sterling": "GB"  
    })  
    updated_data['TO_CURRENCY'] = updated_data['TO_CURRENCY'].replace({  
        "US Dollar": "USD",  
        "Euro": "Eur",  
        "UK Pound Sterling": "GB"  
    })  
    
    updated_data = updated_data[(updated_data.FROM_CURRENCY.isin(["USD", "Eur", "GB"])) |
    (updated_data.TO_CURRENCY.isin(["USD", "Eur", "GB"]))]
    return updated_data 

def save_currency_data(data, filename):
    """Save the currency data to a CSV file"""
    try:
        file_path = f"D:/workspace/images/collected_images/{filename}"
        
        data.to_csv(file_path, index=False)
        print(f"Data saved to {file_path}")
    except Exception as e:
        print(f"Failed to save data to {filename}: {e}")

def main():
    
    url = 'https://www.forex.com.pk/open_market_rates.asp'
    data = fetch_currency_data(url)
    processed_data = process_currency_data(data)
    if processed_data is not None:
        print(processed_data)
        
        updated_data = add_new_row(processed_data) 
        
        save_currency_data(updated_data, "currency_data.csv")

if __name__ == "__main__":
    main()
# Out:
#         FROM_CURRENCY TO_CURRENCY CONVERSION_DATE CONVERSION_TYPE  \
# 0   Australian Dollar         PKR     20-Dec-2024       Corporate
# 1       Bahrain Dinar         PKR     20-Dec-2024       Corporate
# 2     Canadian Dollar         PKR     20-Dec-2024       Corporate
# 3          China Yuan         PKR     20-Dec-2024       Corporate
# 4        Danish Krone         PKR     20-Dec-2024       Corporate
# 5                Euro         PKR     20-Dec-2024       Corporate
# 6    Hong Kong Dollar         PKR     20-Dec-2024       Corporate
# 7        Indian Rupee         PKR     20-Dec-2024       Corporate
# 8        Japanese Yen         PKR     20-Dec-2024       Corporate
# 9       Kuwaiti Dinar         PKR     20-Dec-2024       Corporate
# 10  Malaysian Ringgit         PKR     20-Dec-2024       Corporate
# 11       NewZealand $         PKR     20-Dec-2024       Corporate
# 12   Norwegians Krone         PKR     20-Dec-2024       Corporate
# 13        Omani Riyal         PKR     20-Dec-2024       Corporate
# 14       Qatari Riyal         PKR     20-Dec-2024       Corporate
# 15        Saudi Riyal         PKR     20-Dec-2024       Corporate
# 16   Singapore Dollar         PKR     20-Dec-2024       Corporate
# 17     Swedish Korona         PKR     20-Dec-2024       Corporate
# 18        Swiss Franc         PKR     20-Dec-2024       Corporate
# 19          Thai Bhat         PKR     20-Dec-2024       Corporate
# 20       U.A.E Dirham         PKR     20-Dec-2024       Corporate
# 21  UK Pound Sterling         PKR     20-Dec-2024       Corporate
# 22          US Dollar         PKR     20-Dec-2024       Corporate
#
#     CONVERSION_RATE STATUS_CODE CREATION_DATE CREATED_BY LAST_UPDATE_DATE  \
# 0            176.00           C   20-Dec-2024       1115      20-Dec-2024
# 1            742.95           C   20-Dec-2024       1115      20-Dec-2024
# 2            196.82           C   20-Dec-2024       1115      20-Dec-2024
# 3             38.39           C   20-Dec-2024       1115      20-Dec-2024
# 4             39.55           C   20-Dec-2024       1115      20-Dec-2024
# 5            289.20           C   20-Dec-2024       1115      20-Dec-2024
# 6             35.77           C   20-Dec-2024       1115      20-Dec-2024
# 7              3.28           C   20-Dec-2024       1115      20-Dec-2024
# 8              1.91           C   20-Dec-2024       1115      20-Dec-2024
# 9            907.00           C   20-Dec-2024       1115      20-Dec-2024
# 10            62.19           C   20-Dec-2024       1115      20-Dec-2024
# 11           158.93           C   20-Dec-2024       1115      20-Dec-2024
# 12            24.71           C   20-Dec-2024       1115      20-Dec-2024
# 13           727.80           C   20-Dec-2024       1115      20-Dec-2024
# 14            76.40           C   20-Dec-2024       1115      20-Dec-2024
# 15            74.25           C   20-Dec-2024       1115      20-Dec-2024
# 16           206.99           C   20-Dec-2024       1115      20-Dec-2024
# 17            25.33           C   20-Dec-2024       1115      20-Dec-2024
# 18           314.09           C   20-Dec-2024       1115      20-Dec-2024
# 19             8.15           C   20-Dec-2024       1115      20-Dec-2024
# 20            76.05           C   20-Dec-2024       1115      20-Dec-2024
# 21           350.80           C   20-Dec-2024       1115      20-Dec-2024
# 22           279.40           C   20-Dec-2024       1115      20-Dec-2024
#
#    LAST_UPDATED_BY LAST_UPDATE_LOGIN
# 0             1115              1115
# 1             1115              1115
# 2             1115              1115
# 3             1115              1115
# 4             1115              1115
# 5             1115              1115
# 6             1115              1115
# 7             1115              1115
# 8             1115              1115
# 9             1115              1115
# 10            1115              1115
# 11            1115              1115
# 12            1115              1115
# 13            1115              1115
# 14            1115              1115
# 15            1115              1115
# 16            1115              1115
# 17            1115              1115
# 18            1115              1115
# 19            1115              1115
# 20            1115              1115
# 21            1115              1115
# 22            1115              1115
# Data saved to D:/workspace/images/collected_images/currency_data.csv
